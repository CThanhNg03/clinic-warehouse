# %% [markdown]
# # Data Exploration
# This is notebook focusing on understanding EHR and DICOM data structure

# %% [markdown]
# ## Adjust data
# This section of the notebook focuses on adjusting and transforming the data from various FHIR resources. The data is loaded, flattened, and normalized to ensure consistency and ease of analysis.

# %%
import os
import dotenv

dotenv.load_dotenv('../.env')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
dpath = os.getenv('EHR_PATH')

# # Get the first of first directory in EHR data
# first_dir = os.path.join(dpath, os.listdir(dpath)[0])
# test_dir = os.path.join(first_dir, os.listdir(first_dir)[0])
# items_in_test_dir = os.listdir(test_dir)

# Get all directories in first dir
first_dir = os.path.join(dpath, os.listdir(dpath)[0])
items_in_test_dir = []
for dir in os.listdir(first_dir):
    dipath = os.path.join(first_dir, dir)
    items_in_dir = [os.path.join(dipath, item) for item in os.listdir(dipath)]
    items_in_test_dir.extend(items_in_dir)

len(items_in_test_dir)
# Out:
# 531

# %%
# Create meta data frame
meta_df = pd.DataFrame(items_in_test_dir, columns=['path'])

def get_meta_data(row):
    path = row['path']
    with open(path) as f:
        data = json.load(f)
    row['data'] = data
    return row

meta_df = meta_df.apply(get_meta_data, axis=1)

# Print the keys of the first data
print(meta_df['data'][0].keys())
# Out:
# dict_keys(['type', 'entry', 'resourceType'])

# %%
def flatten_data(row):
    """
    Flatten the data dictionary into the row
    """
    data = row['data']
    for key in data.keys():
        row[key] = data[key]
    return row

# %%
def flatten_object(row):
    for field in row:
        print(field)
        if isinstance(field, (dict, object)):
            try:
                for key in row[field]:
                    row[field + '_' + key] = row[field][key]
                del row[field]
            except:
                pass

# %%
meta_df = meta_df.apply(flatten_data, axis=1)

meta_df.drop(columns=['data'], inplace=True)
meta_df.head()
# Out:
#                                                 path        type  \
# 0  E:\Thesis\project\.data\fhir\00\000\0000e4c0-2...  collection
# 1  E:\Thesis\project\.data\fhir\00\000\000148c5-9...  collection
# 2  E:\Thesis\project\.data\fhir\00\000\00023d13-0...  collection
# 3  E:\Thesis\project\.data\fhir\00\000\0002bd05-b...  collection
# 4  E:\Thesis\project\.data\fhir\00\000\0003292a-9...  collection
#
#                                                entry resourceType
# 0  [{'fullUrl': 'urn:uuid:80bb41d3-ebb4-42e6-b087...       Bundle
# 1  [{'fullUrl': 'urn:uuid:bb357dc7-2f8a-444e-ba57...       Bundle
# 2  [{'fullUrl': 'urn:uuid:c71d235f-9b58-4106-b744...       Bundle
# 3  [{'fullUrl': 'urn:uuid:509474a0-baf3-48f2-a595...       Bundle
# 4  [{'fullUrl': 'urn:uuid:f10fd607-58ce-4be6-b1bd...       Bundle

# %%
# Explode the entry column
all_df = meta_df.copy().explode('entry').reset_index(drop=True)

all_df.rename(columns={'entry': 'data'}, inplace=True)
all_df = all_df.apply(flatten_data, axis=1)
all_df.drop(columns=['resourceType', 'type', 'data'], inplace=True)
all_df['resourceType'] = all_df['resource'].apply(lambda x: x['resourceType'])
all_df.head()
# Out:
#                                          fullUrl  \
# 0  urn:uuid:80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 1  urn:uuid:2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 2  urn:uuid:593c21c4-8cce-47cd-bd70-41e4a7b25557
# 3  urn:uuid:1f954180-ec49-455a-95aa-3b7414ffeab6
# 4  urn:uuid:556966e3-42a8-4359-838a-8771dd2a2a23
#
#                                                 path  \
# 0  E:\Thesis\project\.data\fhir\00\000\0000e4c0-2...
# 1  E:\Thesis\project\.data\fhir\00\000\0000e4c0-2...
# 2  E:\Thesis\project\.data\fhir\00\000\0000e4c0-2...
# 3  E:\Thesis\project\.data\fhir\00\000\0000e4c0-2...
# 4  E:\Thesis\project\.data\fhir\00\000\0000e4c0-2...
#
#                                             resource resourceType
# 0  {'id': '80bb41d3-ebb4-42e6-b087-6ee89b0463a9',...      Patient
# 1  {'id': '2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6',...    Encounter
# 2  {'id': '593c21c4-8cce-47cd-bd70-41e4a7b25557',...    Condition
# 3  {'id': '1f954180-ec49-455a-95aa-3b7414ffeab6',...  Observation
# 4  {'id': '556966e3-42a8-4359-838a-8771dd2a2a23',...  Observation

# %%
# Get the unique resource types
all_df['resourceType'].unique()
# Out:
# array(['Patient', 'Encounter', 'Condition', 'Observation', 'Immunization',
#        'CarePlan', 'Procedure', 'DiagnosticReport', 'MedicationRequest',
#        'AllergyIntolerance'], dtype=object)

# %%
from typing import Dict

detail_dfs: Dict[str, pd.DataFrame] = {
    resource_type: all_df.copy()[all_df['resourceType'] == resource_type]
    for resource_type in all_df['resourceType'].unique()
}
for df in detail_dfs:
    detail_dfs[df].drop(columns=['fullUrl', 'path'], inplace=True)
    detail_dfs[df].rename(columns={'resource': 'data'}, inplace=True)
    normalized_data = pd.json_normalize(detail_dfs[df]['data'])
    detail_dfs[df] = pd.concat([detail_dfs[df].drop(columns=['data']), normalized_data], axis=1)
    print(f"\nResource type: {df}")
    detail_dfs[df].info(show_counts=False, memory_usage=False)
# Out:
# Resource type: Patient
# <class 'pandas.core.frame.DataFrame'>
# Index: 1054 entries, 0 to 530
# Data columns (total 17 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   resourceType          object
#  1   id                    object
#  2   extension             object
#  3   identifier            object
#  4   name                  object
#  5   telecom               object
#  6   gender                object
#  7   birthDate             object
#  8   address               object
#  9   multipleBirthBoolean  object
#  10  photo                 object
#  11  resourceType          object
#  12  text.status           object
#  13  text.div              object
#  14  maritalStatus.coding  object
#  15  deceasedDateTime      object
#  16  multipleBirthInteger  float64
# dtypes: float64(1), object(16)
# Resource type: Encounter
# <class 'pandas.core.frame.DataFrame'>
# Index: 9472 entries, 1 to 5101
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resourceType       object
#  1   id                 object
#  2   status             object
#  3   type               object
#  4   resourceType       object
#  5   class.code         object
#  6   patient.reference  object
#  7   period.start       object
#  8   period.end         object
#  9   reason.coding      object
# dtypes: object(10)
# Resource type: Condition
# <class 'pandas.core.frame.DataFrame'>
# Index: 3711 entries, 2 to 1916
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   resourceType        object
#  1   id                  object
#  2   clinicalStatus      object
#  3   verificationStatus  object
#  4   onsetDateTime       object
#  5   abatementDateTime   object
#  6   resourceType        object
#  7   code.coding         object
#  8   subject.reference   object
#  9   context.reference   object
# dtypes: object(10)
# Resource type: Observation
# <class 'pandas.core.frame.DataFrame'>
# Index: 28697 entries, 3 to 19372
# Data columns (total 14 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   resourceType                 object
#  1   id                           object
#  2   status                       object
#  3   effectiveDateTime            object
#  4   resourceType                 object
#  5   code.coding                  object
#  6   subject.reference            object
#  7   encounter.reference          object
#  8   valueQuantity.value          float64
#  9   valueQuantity.unit           object
#  10  valueQuantity.system         object
#  11  valueQuantity.code           object
#  12  component                    object
#  13  valueCodeableConcept.coding  object
# dtypes: float64(1), object(13)
# Resource type: Immunization
# <class 'pandas.core.frame.DataFrame'>
# Index: 6976 entries, 7 to 3685
# Data columns (total 9 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   resourceType         object
#  1   status               object
#  2   date                 object
#  3   wasNotGiven          object
#  4   primarySource        object
#  5   resourceType         object
#  6   vaccineCode.coding   object
#  7   patient.reference    object
#  8   encounter.reference  object
# dtypes: object(9)
# Resource type: CarePlan
# <class 'pandas.core.frame.DataFrame'>
# Index: 1945 entries, 8 to 987
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resourceType       object
#  1   status             object
#  2   category           object
#  3   activity           object
#  4   resourceType       object
#  5   subject.reference  object
#  6   context.reference  object
#  7   period.start       object
#  8   period.end         object
#  9   addresses          object
# dtypes: object(10)
# Resource type: Procedure
# <class 'pandas.core.frame.DataFrame'>
# Index: 4810 entries, 13 to 2466
# Data columns (total 11 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   resourceType               object
#  1   status                     object
#  2   resourceType               object
#  3   code.coding                object
#  4   code.text                  object
#  5   subject.reference          object
#  6   encounter.reference        object
#  7   performedPeriod.start      object
#  8   performedPeriod.end        object
#  9   performedDateTime          object
#  10  reasonReference.reference  object
# dtypes: object(11)
# Resource type: DiagnosticReport
# <class 'pandas.core.frame.DataFrame'>
# Index: 2343 entries, 23 to 1188
# Data columns (total 11 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   resourceType         object
#  1   id                   object
#  2   status               object
#  3   effectiveDateTime    object
#  4   issued               object
#  5   performer            object
#  6   result               object
#  7   resourceType         object
#  8   code.coding          object
#  9   subject.reference    object
#  10  encounter.reference  object
# dtypes: object(11)
# Resource type: MedicationRequest
# <class 'pandas.core.frame.DataFrame'>
# Index: 2544 entries, 156 to 1290
# Data columns (total 17 columns):
#  #   Column                                         Dtype
# ---  ------                                         -----
#  0   resourceType                                   object
#  1   status                                         object
#  2   dateWritten                                    object
#  3   reasonReference                                object
#  4   dosageInstruction                              object
#  5   resourceType                                   object
#  6   stage.coding                                   object
#  7   medicationCodeableConcept.coding               object
#  8   patient.reference                              object
#  9   context.reference                              object
#  10  dispenseRequest.numberOfRepeatsAllowed         float64
#  11  dispenseRequest.quantity.value                 float64
#  12  dispenseRequest.quantity.unit                  object
#  13  dispenseRequest.expectedSupplyDuration.value   float64
#  14  dispenseRequest.expectedSupplyDuration.unit    object
#  15  dispenseRequest.expectedSupplyDuration.system  object
#  16  dispenseRequest.expectedSupplyDuration.code    object
# dtypes: float64(3), object(14)
# Resource type: AllergyIntolerance
# <class 'pandas.core.frame.DataFrame'>
# Index: 556 entries, 654 to 277
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resourceType       object
#  1   clinicalStatus     object
#  2   type               object
#  3   category           object
#  4   criticality        object
#  5   assertedDate       object
#  6   resourceType       object
#  7   code.coding        object
#  8   patient.reference  object
# dtypes: object(9)

# %% [markdown]
# If the field in the dataframe is a list, it should be stored in a new sub dataframe.

# %%
def explode_df(row, df):
    """
    This function separates the list columns into separate dataframes from the dataframe with ID
    """
    cols_to_remove = []
    cols = detail_dfs[df].columns
    try:
        id = row['id']
    except:
        return cols_to_remove
    for col in cols:
        if isinstance(row[col], list):
            new_df = f'{df}.{col}'
            if new_df not in detail_dfs:
                detail_dfs[new_df] = pd.DataFrame()
            new_row = pd.DataFrame(row[col])
            new_row[f'{df}_id'] = id
            detail_dfs[new_df] = pd.concat([detail_dfs[new_df], new_row], ignore_index=True)
            cols_to_remove.append(col)
    return cols_to_remove

main_dfs = [df if '.' not in df else df.split('.')[0] for df in detail_dfs]
for df in main_dfs:
    print(f"Exploding {df}")
    cols_to_remove = detail_dfs[df].apply(lambda x: explode_df(x, df), axis=1)
    cols_to_remove = [item for sublist in cols_to_remove for item in sublist]
    detail_dfs[df].drop(columns=cols_to_remove, inplace=True)
# Out:
# Exploding Patient
# Exploding Encounter
# Exploding Condition
# Exploding Observation
# Exploding Immunization
# Exploding CarePlan
# Exploding Procedure
# Exploding DiagnosticReport
# Exploding MedicationRequest
# Exploding AllergyIntolerance

# %%
for df in detail_dfs:
    print(f"\nResource type: {df}")
    detail_dfs[df].info(show_counts=False, memory_usage=False)
# Out:
# Resource type: Patient
# <class 'pandas.core.frame.DataFrame'>
# Index: 1054 entries, 0 to 530
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   resourceType          object
#  1   id                    object
#  2   gender                object
#  3   birthDate             object
#  4   multipleBirthBoolean  object
#  5   resourceType          object
#  6   text.status           object
#  7   text.div              object
#  8   deceasedDateTime      object
#  9   multipleBirthInteger  float64
# dtypes: float64(1), object(9)
# Resource type: Encounter
# <class 'pandas.core.frame.DataFrame'>
# Index: 9472 entries, 1 to 5101
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resourceType       object
#  1   id                 object
#  2   status             object
#  3   resourceType       object
#  4   class.code         object
#  5   patient.reference  object
#  6   period.start       object
#  7   period.end         object
# dtypes: object(8)
# Resource type: Condition
# <class 'pandas.core.frame.DataFrame'>
# Index: 3711 entries, 2 to 1916
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   resourceType        object
#  1   id                  object
#  2   clinicalStatus      object
#  3   verificationStatus  object
#  4   onsetDateTime       object
#  5   abatementDateTime   object
#  6   resourceType        object
#  7   subject.reference   object
#  8   context.reference   object
# dtypes: object(9)
# Resource type: Observation
# <class 'pandas.core.frame.DataFrame'>
# Index: 28697 entries, 3 to 19372
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   resourceType          object
#  1   id                    object
#  2   status                object
#  3   effectiveDateTime     object
#  4   resourceType          object
#  5   subject.reference     object
#  6   encounter.reference   object
#  7   valueQuantity.value   float64
#  8   valueQuantity.unit    object
#  9   valueQuantity.system  object
#  10  valueQuantity.code    object
# dtypes: float64(1), object(10)
# Resource type: Immunization
# <class 'pandas.core.frame.DataFrame'>
# Index: 6976 entries, 7 to 3685
# Data columns (total 9 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   resourceType         object
#  1   status               object
#  2   date                 object
#  3   wasNotGiven          object
#  4   primarySource        object
#  5   resourceType         object
#  6   vaccineCode.coding   object
#  7   patient.reference    object
#  8   encounter.reference  object
# dtypes: object(9)
# Resource type: CarePlan
# <class 'pandas.core.frame.DataFrame'>
# Index: 1945 entries, 8 to 987
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resourceType       object
#  1   status             object
#  2   category           object
#  3   activity           object
#  4   resourceType       object
#  5   subject.reference  object
#  6   context.reference  object
#  7   period.start       object
#  8   period.end         object
#  9   addresses          object
# dtypes: object(10)
# Resource type: Procedure
# <class 'pandas.core.frame.DataFrame'>
# Index: 4810 entries, 13 to 2466
# Data columns (total 11 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   resourceType               object
#  1   status                     object
#  2   resourceType               object
#  3   code.coding                object
#  4   code.text                  object
#  5   subject.reference          object
#  6   encounter.reference        object
#  7   performedPeriod.start      object
#  8   performedPeriod.end        object
#  9   performedDateTime          object
#  10  reasonReference.reference  object
# dtypes: object(11)
# Resource type: DiagnosticReport
# <class 'pandas.core.frame.DataFrame'>
# Index: 2343 entries, 23 to 1188
# Data columns (total 8 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   resourceType         object
#  1   id                   object
#  2   status               object
#  3   effectiveDateTime    object
#  4   issued               object
#  5   resourceType         object
#  6   subject.reference    object
#  7   encounter.reference  object
# dtypes: object(8)
# Resource type: MedicationRequest
# <class 'pandas.core.frame.DataFrame'>
# Index: 2544 entries, 156 to 1290
# Data columns (total 17 columns):
#  #   Column                                         Dtype
# ---  ------                                         -----
#  0   resourceType                                   object
#  1   status                                         object
#  2   dateWritten                                    object
#  3   reasonReference                                object
#  4   dosageInstruction                              object
#  5   resourceType                                   object
#  6   stage.coding                                   object
#  7   medicationCodeableConcept.coding               object
#  8   patient.reference                              object
#  9   context.reference                              object
#  10  dispenseRequest.numberOfRepeatsAllowed         float64
#  11  dispenseRequest.quantity.value                 float64
#  12  dispenseRequest.quantity.unit                  object
#  13  dispenseRequest.expectedSupplyDuration.value   float64
#  14  dispenseRequest.expectedSupplyDuration.unit    object
#  15  dispenseRequest.expectedSupplyDuration.system  object
#  16  dispenseRequest.expectedSupplyDuration.code    object
# dtypes: float64(3), object(14)
# Resource type: AllergyIntolerance
# <class 'pandas.core.frame.DataFrame'>
# Index: 556 entries, 654 to 277
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resourceType       object
#  1   clinicalStatus     object
#  2   type               object
#  3   category           object
#  4   criticality        object
#  5   assertedDate       object
#  6   resourceType       object
#  7   code.coding        object
#  8   patient.reference  object
# dtypes: object(9)
# Resource type: Patient.extension
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 6 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   url                   object
#  1   valueCodeableConcept  object
#  2   valueAddress          object
#  3   valueString           object
#  4   Patient_id            object
#  5   valueCode             object
# dtypes: object(6)
# Resource type: Patient.identifier
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708 entries, 0 to 1707
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   system      object
#  1   value       object
#  2   type        object
#  3   Patient_id  object
# dtypes: object(4)
# Resource type: Patient.name
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   use         object
#  1   family      object
#  2   given       object
#  3   prefix      object
#  4   Patient_id  object
#  5   suffix      object
# dtypes: object(6)
# Resource type: Patient.telecom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   extension   object
#  1   system      object
#  2   value       object
#  3   use         object
#  4   Patient_id  object
# dtypes: object(5)
# Resource type: Patient.address
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   extension   object
#  1   line        object
#  2   city        object
#  3   state       object
#  4   postalCode  object
#  5   Patient_id  object
# dtypes: object(6)
# Resource type: Patient.photo
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   contentType  object
#  1   data         object
#  2   title        object
#  3   Patient_id   object
# dtypes: object(4)
# Resource type: Patient.maritalStatus.coding
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   system      object
#  1   code        object
#  2   Patient_id  object
# dtypes: object(3)
# Resource type: Encounter.type
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5103 entries, 0 to 5102
# Data columns (total 3 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   coding        object
#  1   text          object
#  2   Encounter_id  object
# dtypes: object(3)
# Resource type: Encounter.reason.coding
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   system        object
#  1   code          object
#  2   display       object
#  3   Encounter_id  object
# dtypes: object(4)
# Resource type: Condition.code.coding
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   system        object
#  1   code          object
#  2   display       object
#  3   Condition_id  object
# dtypes: object(4)
# Resource type: Observation.code.coding
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19379 entries, 0 to 19378
# Data columns (total 4 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   system          object
#  1   code            object
#  2   display         object
#  3   Observation_id  object
# dtypes: object(4)
# Resource type: Observation.component
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4836 entries, 0 to 4835
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   code            object
#  1   valueQuantity   object
#  2   Observation_id  object
# dtypes: object(3)
# Resource type: Observation.valueCodeableConcept.coding
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 4 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   system          object
#  1   code            object
#  2   display         object
#  3   Observation_id  object
# dtypes: object(4)
# Resource type: DiagnosticReport.performer
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189 entries, 0 to 1188
# Data columns (total 2 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   display              object
#  1   DiagnosticReport_id  object
# dtypes: object(2)
# Resource type: DiagnosticReport.result
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7118 entries, 0 to 7117
# Data columns (total 3 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   reference            object
#  1   display              object
#  2   DiagnosticReport_id  object
# dtypes: object(3)
# Resource type: DiagnosticReport.code.coding
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189 entries, 0 to 1188
# Data columns (total 4 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   system               object
#  1   code                 object
#  2   display              object
#  3   DiagnosticReport_id  object
# dtypes: object(4)

# %% [markdown]
# ### Patient adjust data

# %% [markdown]
# This extension in the patient data is unclear. We will perform data exploration and make necessary changes to it.

# %%
df = detail_dfs['Patient.extension']
df['url'].unique()
df['extension_type'] = df['url'].apply(lambda x: x.split('/')[-1])
df.head()
# Out:
#                                                  url  \
# 0  http://hl7.org/fhir/StructureDefinition/us-cor...
# 1  http://hl7.org/fhir/StructureDefinition/us-cor...
# 2  http://standardhealthrecord.org/fhir/extension...
# 3  http://hl7.org/fhir/StructureDefinition/patien...
# 4  http://standardhealthrecord.org/fhir/extension...
#
#                                 valueCodeableConcept  \
# 0  {'coding': [{'system': 'http://hl7.org/fhir/v3...
# 1  {'coding': [{'system': 'http://hl7.org/fhir/v3...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                         valueAddress        valueString  \
# 0                                NaN                NaN
# 1                                NaN                NaN
# 2  {'city': 'Lowell', 'state': 'MA'}                NaN
# 3                                NaN   Lukas138 Beer653
# 4                                NaN  Gerson187 Hayes97
#
#                              Patient_id valueCode             extension_type
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN               us-core-race
# 1  80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN          us-core-ethnicity
# 2  80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN               placeOfBirth
# 3  80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN  patient-mothersMaidenName
# 4  80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN                fathersName

# %%
for field in ['valueCodeableConcept', 'valueAddress', 'valueCode', 'valueString']:
    print(df[field].value_counts())
# Out:
# valueCodeableConcept
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Ethnicity', 'code': '2186-5', 'display': 'Nonhispanic'}], 'text': 'ethnicity'}         480
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Race', 'code': '2106-3', 'display': 'White'}], 'text': 'race'}                         412
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Race', 'code': '2131-1', 'display': 'Other'}], 'text': 'race'}                          51
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Ethnicity', 'code': '2180-8', 'display': 'Puerto_rican'}], 'text': 'ethnicity'}         37
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Race', 'code': '2054-5', 'display': 'Black'}], 'text': 'race'}                          35
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Race', 'code': '2028-9', 'display': 'Asian'}], 'text': 'race'}                          33
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Ethnicity', 'code': '2148-5', 'display': 'Mexican'}], 'text': 'ethnicity'}               9
# {'coding': [{'system': 'http://hl7.org/fhir/v3/Ethnicity', 'code': '2155-0', 'display': 'Central_american'}], 'text': 'ethnicity'}      5
# Name: count, dtype: int64
# valueAddress
# {'city': 'Boston', 'state': 'MA'}          61
# {'city': 'New Bedford', 'state': 'MA'}     13
# {'city': 'Worcester', 'state': 'MA'}       12
# {'city': 'Springfield', 'state': 'MA'}     11
# {'city': 'Cambridge', 'state': 'MA'}        9
#                                            ..
# {'city': 'Mashpee', 'state': 'MA'}          1
# {'city': 'Middleton', 'state': 'MA'}        1
# {'city': 'Pembroke', 'state': 'MA'}         1
# {'city': 'Methuen Town', 'state': 'MA'}     1
# {'city': 'Montgomery', 'state': 'MA'}       1
# Name: count, Length: 181, dtype: int64
# valueCode
# Multiple    9
# Name: count, dtype: int64
# valueString
# Blaise186 Reilly26        2
# Reba936 Schultz947        1
# Austyn58 Stiedemann710    1
# Warren80 Luettgen376      1
# Max360 Bernier588         1
#                          ..
# Noemie461 Swift621        1
# Keeley742 Dare857         1
# Velva702 Raynor174        1
# Meredith883 Padberg232    1
# Gerson187 Hayes97         1
# Name: count, Length: 1061, dtype: int64

# %% [markdown]
# The actual meaning value in 'valueCodeableConcept' is display; \
# 'valueAddress' could be displayed as string, seperated by comma; \
# 'valueCode' can also be displayed as string. \
# I should extract all of them and store these values into 'value' field as a list.

# %%
def extract_extension(row):
    if pd.notna(row['valueCodeableConcept']):
        if isinstance(row['valueCodeableConcept'], dict):
            row['value'] = "".join([v['display'] for v in row['valueCodeableConcept']['coding']])
    if pd.notna(row['valueAddress']):
        if isinstance(row['valueAddress'], dict):
            row['value'] = ", ".join(row['valueAddress'].values())
    if pd.notna(row['valueCode']):
        row['value'] = row['valueCode']
    if pd.notna(row['valueString']):
        row['value'] = row['valueString']
    return row

df = df.apply(extract_extension, axis=1)
df.drop(columns=['valueCodeableConcept', 'valueAddress', 'valueCode', 'valueString', 'url'], inplace=True)

detail_dfs['Patient.extension'] = df
df.head()
# Out:
#                              Patient_id             extension_type  \
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9               us-core-race
# 1  80bb41d3-ebb4-42e6-b087-6ee89b0463a9          us-core-ethnicity
# 2  80bb41d3-ebb4-42e6-b087-6ee89b0463a9               placeOfBirth
# 3  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  patient-mothersMaidenName
# 4  80bb41d3-ebb4-42e6-b087-6ee89b0463a9                fathersName
#
#                value
# 0              White
# 1        Nonhispanic
# 2         Lowell, MA
# 3   Lukas138 Beer653
# 4  Gerson187 Hayes97

# %%
df = detail_dfs['Patient.address']
df.explode('extension')
def explode_latitud_longitud(row):
    if pd.notna(row['extension']):
        if isinstance(row['extension'], list):
            for ext in row['extension'][0]['extension']:
                if ext['url'] == 'latitude':
                    row['latitude'] = ext['valueDecimal']
                if ext['url'] == 'longitude':
                    row['longitude'] = ext['valueDecimal']
    return row

df = df.apply(explode_latitud_longitud, axis=1)

# %%
def extract_first_line(row):
	row['line'] = row['line'][0]
	return row

df = df.apply(extract_first_line, axis=1)
df.drop(columns=['extension'], inplace=True)

detail_dfs['Patient.address'] = df
df.head()
# Out:
#                      line        city state postalCode  \
# 0     4711 Powlowski Loop  Shrewsbury    MA      01545
# 1  348 Rodolfo Trafficway     Walpole    MA      02081
# 2          412 Jacey Spur      Dudley    MA      01571
# 3    84443 Axel Mountains  Shrewsbury    MA      01546
# 4        1506 Arvel Route  Burlington    MA      01803
#
#                              Patient_id   latitude  longitude
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  42.311666 -71.701575
# 1  6ca82ef7-49ec-48c7-bc21-ea7ebdb9afe4  42.157578 -71.202704
# 2  42c705df-3b17-4f46-a045-911bd542a5d1  42.068571 -71.950993
# 3  742632b7-8105-4453-80d7-430a065f8010  42.259827 -71.677556
# 4  8fd20752-2123-4486-9395-a1e4922920bd  42.508575 -71.192398

# %%
df = detail_dfs['Patient.telecom']
df = df.explode('extension')
def explode_telecom(row):
    if pd.notna(row['extension']):
        field = row['extension']['url'].split('/')[-1]
        value = [v for v in row['extension'].keys() if v.startswith('value')][0]
        row[field] = row['extension'][value]
    return row
df = df.apply(explode_telecom, axis=1)

# %%
df.drop(columns=['extension'], inplace=True)

detail_dfs['Patient.telecom'] = df
df.head()
# Out:
#   system                  value   use                            Patient_id  \
# 0  phone    493.648.2471 x26272  home  80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 1  phone           954.817.6687  home  6ca82ef7-49ec-48c7-bc21-ea7ebdb9afe4
# 2  phone      133-061-0037 x987  home  42c705df-3b17-4f46-a045-911bd542a5d1
# 3  phone   (494) 819-8705 x4766  home  742632b7-8105-4453-80d7-430a065f8010
# 4  phone  (439) 334-9923 x88504  home  8fd20752-2123-4486-9395-a1e4922920bd
#
#    okayToLeaveMessage
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True

# %%
df = detail_dfs['Patient.name']
df = df.explode(['given', 'prefix', 'suffix'])

detail_dfs['Patient.name'] = df
df[df['suffix'].notna()]
# Out:
#           use      family       given prefix  \
# 11   official  Reichel133    Caleb562   Mrs.
# 400  official    Beatty45   Felipe505    Ms.
# 486  official  Osinski213  Sabrina736   Mrs.
#
#                                Patient_id suffix
# 11   086bd6d1-a84c-4fa7-98ae-39b78d39113b    PhD
# 400  e6e7c630-73c8-48d3-8f1b-05638b4162a1     JD
# 486  e86759ad-c212-4a26-8b73-041c829bf5c3     JD

# %%
df = detail_dfs['Patient.identifier']

df['type'] = df['system'].apply(lambda x: x.split('/')[-1])
df.drop(columns=['system'], inplace=True)

detail_dfs['Patient.identifier'] = df
df.head()
# Out:
#                                   value                              type  \
# 0  0000e4c0-2057-4c43-a90e-33891c7bc097                           synthea
# 1                             999664433                            us-ssn
# 2                             S99957033  urn:oid:2.16.840.1.113883.4.3.25
# 3  001be922-fe94-4542-84e9-43623e820da7                           synthea
# 4                             999921242                            us-ssn
#
#                              Patient_id
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 1  80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 2  80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 3  6ca82ef7-49ec-48c7-bc21-ea7ebdb9afe4
# 4  6ca82ef7-49ec-48c7-bc21-ea7ebdb9afe4

# %%
df = detail_dfs['Patient.maritalStatus.coding']
df.drop(columns=['system'], inplace=True)

detail_dfs['Patient.maritalStatus'] = df

df.head()
# Out:
#   code                            Patient_id
# 0    M  80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 1    M  6ca82ef7-49ec-48c7-bc21-ea7ebdb9afe4
# 2    M  42c705df-3b17-4f46-a045-911bd542a5d1
# 3    S  742632b7-8105-4453-80d7-430a065f8010
# 4    M  8fd20752-2123-4486-9395-a1e4922920bd

# %%
# Rename 'code' column to 'maritalStatus' in Patient.maritalStatus.coding
detail_dfs['Patient.maritalStatus.coding'].rename(columns={'code': 'maritalStatus'}, inplace=True)

# Merge Patient.maritalStatus.coding with Patient
merged_df = detail_dfs['Patient'].merge(detail_dfs['Patient.maritalStatus.coding'], left_on='id', right_on='Patient_id', how='left')

# Drop the redundant 'Patient_id' column
merged_df.drop(columns=['Patient_id'], inplace=True)

# Update the detail_dfs dictionary with the merged dataframe
detail_dfs['Patient'] = merged_df

# Display the merged dataframe
merged_df.head()
# Out:
#   resourceType                                    id  gender   birthDate  \
# 0      Patient  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  female  1959-08-09
# 1      Patient  6ca82ef7-49ec-48c7-bc21-ea7ebdb9afe4  female  1936-05-13
# 2      Patient  42c705df-3b17-4f46-a045-911bd542a5d1    male  1948-10-05
# 3      Patient  742632b7-8105-4453-80d7-430a065f8010  female  1967-03-29
# 4      Patient  8fd20752-2123-4486-9395-a1e4922920bd  female  1982-02-10
#
#   multipleBirthBoolean resourceType text.status  \
# 0                False      Patient   generated
# 1                False      Patient   generated
# 2                False      Patient   generated
# 3                False      Patient   generated
# 4                False      Patient   generated
#
#                                             text.div deceasedDateTime  \
# 0  <div>Generated by <a href="https://github.com/...              NaN
# 1  <div>Generated by <a href="https://github.com/...              NaN
# 2  <div>Generated by <a href="https://github.com/...              NaN
# 3  <div>Generated by <a href="https://github.com/...              NaN
# 4  <div>Generated by <a href="https://github.com/...              NaN
#
#    multipleBirthInteger maritalStatus
# 0                   NaN             M
# 1                   NaN             M
# 2                   NaN             M
# 3                   NaN             S
# 4                   NaN             M

# %%
df = detail_dfs['Patient']

# Adjust the multipleBirthInteger column
df.loc[df['multipleBirthInteger'].notna() & (df['multipleBirthInteger'] > 0), 'multipleBirthBoolean'] = True

df['birthDate'] = pd.to_datetime(df['birthDate'])
df.drop(columns=['text.status', 'text.div', 'resourceType'], inplace=True)

detail_dfs['Patient'] = df
df.head()
# Out:
#                                      id  gender  birthDate  \
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  female 1959-08-09
# 1  6ca82ef7-49ec-48c7-bc21-ea7ebdb9afe4  female 1936-05-13
# 2  42c705df-3b17-4f46-a045-911bd542a5d1    male 1948-10-05
# 3  742632b7-8105-4453-80d7-430a065f8010  female 1967-03-29
# 4  8fd20752-2123-4486-9395-a1e4922920bd  female 1982-02-10
#
#   multipleBirthBoolean deceasedDateTime  multipleBirthInteger maritalStatus
# 0                False              NaN                   NaN             M
# 1                False              NaN                   NaN             M
# 2                False              NaN                   NaN             M
# 3                False              NaN                   NaN             S
# 4                False              NaN                   NaN             M

# %% [markdown]
# ### Encounter adjust data

# %%
df = detail_dfs['Encounter.type']

df = df.explode('coding')

df['type_code'] = df['coding'].apply(lambda x: x['code'])

df.drop(columns=['coding'], inplace=True)

detail_dfs['Encounter.type'] = df
df.head()
# Out:
#                        text                          Encounter_id  type_code
# 0  Encounter for 'check-up'  50c5c5a1-814d-4a53-8407-129c9048f94a  185349003
# 1     Encounter for problem  42d937a4-c092-4d0f-87a5-8eec389cedfa  185347001
# 2      Outpatient Encounter  eaff98cf-528d-4abb-84db-88432aabd27b  185349003
# 3      Outpatient Encounter  a14ca3d2-03e0-4d41-8d1a-77cba28bced7  185349003
# 4      Outpatient Encounter  f64fee9b-4eef-4238-a887-0f702c95e039  185349003

# %%
df = detail_dfs['Encounter.reason.coding']

df.drop(columns=['system'], inplace=True)
df.rename(columns={'code': 'reason_code', 'display': 'reason_display'}, inplace=True)

detail_dfs['Encounter.reason'] = df
df.head()
# Out:
#   reason_code                                    reason_display  \
# 0   307731004  Injury of tendon of the rotator cuff of shoulder
# 1    65363002                                      Otitis media
# 2    72892002                                  Normal pregnancy
# 3   444814009                        Viral sinusitis (disorder)
# 4    65363002                                      Otitis media
#
#                            Encounter_id
# 0  42d937a4-c092-4d0f-87a5-8eec389cedfa
# 1  c344d56e-df7f-4d97-82f0-82682f364eb3
# 2  d8dabaef-d9ff-4570-81ce-54e56248bd67
# 3  45e7a62c-f129-4bb5-8486-97c2b9ac2e72
# 4  c411e6aa-9b2f-4ec5-9549-952ef86189df

# %%
df = detail_dfs['Encounter']

df = df[df['patient.reference'].notna()]

df['period_start'] = pd.to_datetime(df['period.start'])
df['period_end'] = pd.to_datetime(df['period.end'])

df['patient_id'] = df['patient.reference'].apply(lambda x: str(x).split(':')[-1])

type_merged_df = df.merge(detail_dfs['Encounter.type'], left_on='id', right_on='Encounter_id', how='left')
reason_merged_df = type_merged_df.merge(detail_dfs['Encounter.reason.coding'], left_on='id', right_on='Encounter_id', how='left')

reason_merged_df.drop(columns=['Encounter_id_x', 'Encounter_id_y', 'reason_display', 'resourceType', 'period.start', 'period.end', 'patient.reference'], inplace=True)

reason_merged_df = reason_merged_df.rename(columns={'class.code': 'class_code'})

detail_dfs['Encounter'] = reason_merged_df
detail_dfs['Encounter'].head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\4224026848.py:5: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['period_start'] = pd.to_datetime(df['period.start'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\4224026848.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['period_start'] = pd.to_datetime(df['period.start'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\4224026848.py:6: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['period_end'] = pd.to_datetime(df['period.end'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\4224026848.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['period_end'] = pd.to_datetime(df['period.end'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\4224026848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['patient_id'] = df['patient.reference'].apply(lambda x: str(x).split(':')[-1])
#                                      id    status  class.code  \
# 0  50c5c5a1-814d-4a53-8407-129c9048f94a  finished  ambulatory
# 1  42d937a4-c092-4d0f-87a5-8eec389cedfa  finished  ambulatory
# 2  eaff98cf-528d-4abb-84db-88432aabd27b  finished  outpatient
# 3  a14ca3d2-03e0-4d41-8d1a-77cba28bced7  finished  outpatient
# 4  f64fee9b-4eef-4238-a887-0f702c95e039  finished  outpatient
#
#                 period_start                 period_end  \
# 0  2010-12-05 02:33:19-05:00  2010-12-05 03:07:01-05:00
# 1  2012-03-02 19:39:24-05:00  2012-03-02 19:39:24-05:00
# 2  2012-05-22 05:23:52-04:00  2012-05-22 06:23:52-04:00
# 3  2015-01-19 02:00:44-05:00  2015-01-19 03:00:44-05:00
# 4  2011-10-15 19:42:43-04:00  2011-10-15 20:42:43-04:00
#
#                              patient_id                      text  type_code  \
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  Encounter for 'check-up'  185349003
# 1  bb357dc7-2f8a-444e-ba57-8291b6f18bf0     Encounter for problem  185347001
# 2  bb357dc7-2f8a-444e-ba57-8291b6f18bf0      Outpatient Encounter  185349003
# 3  c71d235f-9b58-4106-b744-c554da5e13fa      Outpatient Encounter  185349003
# 4  509474a0-baf3-48f2-a595-67b6e2b34c87      Outpatient Encounter  185349003
#
#   reason_code
# 0         NaN
# 1   307731004
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# Drop the Encounter_id column from Encounter.reason and Encounter.type
detail_dfs['Encounter.reason'].drop(columns=['Encounter_id'], inplace=True)
detail_dfs['Encounter.type'].drop(columns=['Encounter_id'], inplace=True)

# Drop duplicates from Encounter.reason and Encounter.type
detail_dfs['Encounter.reason'].drop_duplicates(inplace=True)
detail_dfs['Encounter.type'].drop_duplicates(inplace=True)

# %%
detail_dfs.pop('Encounter.reason.coding', None)
# Out:
#      reason_code                                     reason_display
# 0      307731004   Injury of tendon of the rotator cuff of shoulder
# 1       65363002                                       Otitis media
# 2       72892002                                   Normal pregnancy
# 3      444814009                         Viral sinusitis (disorder)
# 6       43878008               Streptococcal sore throat (disorder)
# 8      195662009                 Acute viral pharyngitis (disorder)
# 14      10509002                        Acute bronchitis (disorder)
# 16     233678006                                   Childhood asthma
# 38      33737001                                    Fracture of rib
# 39      62106007           Concussion with no loss of consciousness
# 41      36971009                               Sinusitis (disorder)
# 43     232353008  Perennial allergic rhinitis with seasonal vari...
# 47     195967001                                             Asthma
# 49      38822007                                           Cystitis
# 50     267253006                 Fetus with chromosomal abnormality
# 59      74400008                                       Appendicitis
# 83     192127007                   Child attention deficit disorder
# 85      16114001                                  Fracture of ankle
# 89      40275004                                 Contact dermatitis
# 94     301011002           Escherichia coli urinary tract infection
# 120     93761005                Primary malignant neoplasm of colon
# 137     75498004               Acute bacterial sinusitis (disorder)
# 158     82423001                                       Chronic pain
# 173     65966004                                Fracture of forearm
# 177     55680006                                      Drug overdose
# 194     35999006                                      Blighted ovum
# 219    239873007                             Osteoarthritis of knee
# 223     90560007                                               Gout
# 247     58150001                               Fracture of clavicle
# 275     62564004              Concussion with loss of consciousness
# 346     37849005                         Congenital uterine anomaly
# 366    263102004                      Fracture subluxation of wrist
# 401    403190006                                  First degree burn
# 458     95417003                      Primary fibromyalgia syndrome
# 606    444448004       Injury of medial collateral ligament of knee
# 625     26929004                     Alzheimer's disease (disorder)
# 679     24079001                                  Atopic dermatitis
# 968    262574004                                       Bullet wound
# 992    446096008                        Perennial allergic rhinitis
# 1044    68496003                                     Polyp of colon
# 1132   403191005                                 Second degree burn
# 1254   444470001               Injury of anterior cruciate ligament
# 1412   196416002                                    Impacted molars
# 1452   403192003                                  Third degree burn

# %% [markdown]
# ### Condition adjust data

# %%
df = detail_dfs['Condition.code.coding']

df.drop(columns=['system'], inplace=True)
df.rename(columns={'code': 'condition_code', 'display': 'condition_display'}, inplace=True)

detail_dfs['Condition.code'] = df
df.head()
# Out:
#   condition_code            condition_display  \
# 0       15777000                  Prediabetes
# 1      444814009   Viral sinusitis (disorder)
# 2       58150001         Fracture of clavicle
# 3       10509002  Acute bronchitis (disorder)
# 4       10509002  Acute bronchitis (disorder)
#
#                            Condition_id
# 0  4eee0d5a-1999-4af9-8c06-21d8447ab278
# 1  c080d5d5-1c0f-4054-bff6-d062035a6e0e
# 2  ea000905-7a51-4f29-bc3a-8c8cc61a38e6
# 3  76d7f42b-358d-417c-8929-c9144255da69
# 4  93cfd203-eb61-4099-9bd3-73b8fbabf1c8

# %%
detail_dfs['Condition'].head()
# Out:
#     resourceType                                    id clinicalStatus  \
# 2      Condition  4eee0d5a-1999-4af9-8c06-21d8447ab278         active
# 68     Condition  c080d5d5-1c0f-4054-bff6-d062035a6e0e         active
# 69     Condition  ea000905-7a51-4f29-bc3a-8c8cc61a38e6         active
# 112    Condition  76d7f42b-358d-417c-8929-c9144255da69         active
# 114    Condition  93cfd203-eb61-4099-9bd3-73b8fbabf1c8         active
#
#     verificationStatus              onsetDateTime          abatementDateTime  \
# 2            confirmed  1982-12-31T01:10:52-05:00                        NaN
# 68           confirmed  2010-07-21T23:56:22-04:00  2010-08-11T02:28:57-04:00
# 69           confirmed  2010-10-30T03:53:48-04:00  2011-01-15T17:27:00-05:00
# 112          confirmed  2011-12-04T11:01:27-05:00  2011-12-15T14:06:06-05:00
# 114          confirmed  1982-08-18T07:07:52-04:00  1982-08-26T02:57:15-04:00
#
#     resourceType                              subject.reference  \
# 2      Condition  urn:uuid:bb357dc7-2f8a-444e-ba57-8291b6f18bf0
# 68     Condition  urn:uuid:bd0acd69-580e-4896-9974-2ad9d041ca0b
# 69     Condition  urn:uuid:bd0acd69-580e-4896-9974-2ad9d041ca0b
# 112    Condition  urn:uuid:8b47143f-2d3b-4425-a872-569af4ec0818
# 114    Condition  urn:uuid:9bf6df85-12db-49d1-b754-b5adcdbb6115
#
#                                  context.reference
# 2    urn:uuid:aa76d5b2-8587-4dae-b5f9-487ac3a89308
# 68   urn:uuid:65a721f6-f29c-4d45-8b81-c8a32aef22c1
# 69   urn:uuid:2de8efc2-b0a1-414e-acee-2202e0e617ba
# 112  urn:uuid:333ebab1-3eef-43bb-b49c-d5ec064353ab
# 114  urn:uuid:e474dde0-32b2-404c-8622-bc008af313e4

# %%
df = detail_dfs['Condition']

df['onsetDateTime'] = pd.to_datetime(df['onsetDateTime'])
df['abatementDateTime'] = pd.to_datetime(df['abatementDateTime'])

df = df[df['subject.reference'].notna() & df['context.reference'].notna()]

df['patient_id'] = df['subject.reference'].apply(lambda x: str(x).split(':')[-1])
df['encounter_id'] = df['context.reference'].apply(lambda x: str(x).split(':')[-1])

merged_df = df.merge(detail_dfs['Condition.code'], left_on='id', right_on='Condition_id', how='left')

merged_df.drop(columns=['resourceType', 'subject.reference', 'context.reference', 'Condition_id', 'condition_display'], inplace=True)

detail_dfs['Condition'] = merged_df
detail_dfs['Condition'].head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\2041017584.py:3: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['onsetDateTime'] = pd.to_datetime(df['onsetDateTime'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\2041017584.py:4: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['abatementDateTime'] = pd.to_datetime(df['abatementDateTime'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\2041017584.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['patient_id'] = df['subject.reference'].apply(lambda x: str(x).split(':')[-1])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\2041017584.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['encounter_id'] = df['context.reference'].apply(lambda x: str(x).split(':')[-1])
#                                      id clinicalStatus verificationStatus  \
# 0  4eee0d5a-1999-4af9-8c06-21d8447ab278         active          confirmed
# 1  c080d5d5-1c0f-4054-bff6-d062035a6e0e         active          confirmed
# 2  ea000905-7a51-4f29-bc3a-8c8cc61a38e6         active          confirmed
# 3  76d7f42b-358d-417c-8929-c9144255da69         active          confirmed
# 4  93cfd203-eb61-4099-9bd3-73b8fbabf1c8         active          confirmed
#
#                onsetDateTime          abatementDateTime  \
# 0  1982-12-31 01:10:52-05:00                        NaT
# 1  2010-07-21 23:56:22-04:00  2010-08-11 02:28:57-04:00
# 2  2010-10-30 03:53:48-04:00  2011-01-15 17:27:00-05:00
# 3  2011-12-04 11:01:27-05:00  2011-12-15 14:06:06-05:00
# 4  1982-08-18 07:07:52-04:00  1982-08-26 02:57:15-04:00
#
#                              patient_id                          encounter_id  \
# 0  bb357dc7-2f8a-444e-ba57-8291b6f18bf0  aa76d5b2-8587-4dae-b5f9-487ac3a89308
# 1  bd0acd69-580e-4896-9974-2ad9d041ca0b  65a721f6-f29c-4d45-8b81-c8a32aef22c1
# 2  bd0acd69-580e-4896-9974-2ad9d041ca0b  2de8efc2-b0a1-414e-acee-2202e0e617ba
# 3  8b47143f-2d3b-4425-a872-569af4ec0818  333ebab1-3eef-43bb-b49c-d5ec064353ab
# 4  9bf6df85-12db-49d1-b754-b5adcdbb6115  e474dde0-32b2-404c-8622-bc008af313e4
#
#   condition_code
# 0       15777000
# 1      444814009
# 2       58150001
# 3       10509002
# 4       10509002

# %%
detail_dfs['Condition.code'].drop(columns=['Condition_id'], inplace=True)
detail_dfs['Condition.code'].drop_duplicates(inplace=True)
detail_dfs['Condition.code'].value_counts()
# Out:
# condition_code   condition_display
# 10509002         Acute bronchitis (disorder)                                                         1
# 124171000119105  Chronic intractable migraine without aura                                           1
# 127013003        Diabetic renal disease (disorder)                                                   1
# 1501000119109    Proliferative diabetic retinopathy due to type II diabetes mellitus (disorder)      1
# 1551000119108    Nonproliferative diabetic retinopathy due to type 2 diabetes mellitus (disorder)    1
#                                                                                                     ..
# 90560007         Gout                                                                                1
# 90781000119102   Microalbuminuria due to type 2 diabetes mellitus (disorder)                         1
# 93761005         Primary malignant neoplasm of colon                                                 1
# 95417003         Primary fibromyalgia syndrome                                                       1
# 97331000119101   Macular edema and retinopathy due to type 2 diabetes mellitus (disorder)            1
# Name: count, Length: 90, dtype: int64

# %%
detail_dfs.pop('Condition.code.coding', None)
# Out:
#       condition_code                                  condition_display
# 0           15777000                                        Prediabetes
# 1          444814009                         Viral sinusitis (disorder)
# 2           58150001                               Fracture of clavicle
# 3           10509002                        Acute bronchitis (disorder)
# 6           38341003                                       Hypertension
# ...              ...                                                ...
# 1404       403191005                                 Second degree burn
# 1484  97331000119101  Macular edema and retinopathy due to type 2 di...
# 1493       196416002                                    Impacted molars
# 1585       444470001               Injury of anterior cruciate ligament
# 1876       403192003                                  Third degree burn
#
# [90 rows x 2 columns]

# %% [markdown]
# ### Observation adjust data

# %%
df = detail_dfs['Observation.code.coding']

df.drop(columns=['system'], inplace=True)
df.rename(columns={'code': 'observation_code', 'display': 'observation_display'}, inplace=True)

detail_dfs['Observation.code'] = df
df.head()
# Out:
#   observation_code observation_display                        Observation_id
# 0          55284-4      Blood Pressure  7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0
# 1           8302-2         Body Height  cac21874-494f-49f6-8074-1d517a62a7d3
# 2          29463-7         Body Weight  61d46e20-1a26-4fb9-ba74-e21c01bce443
# 3          39156-5     Body Mass Index  62b7938f-5fab-4067-8e6a-fc4f8df284d3
# 4          55284-4      Blood Pressure  2e64f693-fe4f-4405-a0b4-25bd031f0660

# %%
df = detail_dfs['Observation.valueCodeableConcept.coding']

df.drop(columns=['system'], inplace=True)
df.rename(columns={'code': 'value_code', 'display': 'value_display'}, inplace=True)

detail_dfs['Observation.valueCodeableConcept'] = df
df.head()
# Out:
#   value_code                              value_display  \
# 0   87433001             Pulmonary emphysema (disorder)
# 1   87433001             Pulmonary emphysema (disorder)
# 2   55680006                              Drug overdose
# 3  185086009  Chronic obstructive bronchitis (disorder)
# 4   87433001             Pulmonary emphysema (disorder)
#
#                          Observation_id
# 0  018132b0-b4c9-4b67-84a7-90faa6c1931d
# 1  4a4a7a54-396a-442f-9d84-87ffa2fac09c
# 2  fb543c46-051a-4353-8b36-f909a94bdd77
# 3  14b749eb-2a71-4526-9277-532892ea1a91
# 4  11f34a5d-be7e-45bb-b8df-e8d8cacbafca

# %%
df = detail_dfs['Observation.component']

df['code'] = df['code'].apply(lambda x: x['coding'])
df = df.explode('code', ignore_index=True)

# flatten the code column
df.rename(columns={'code': 'component_code'}, inplace=True)
df = pd.concat([pd.json_normalize(df['component_code']), df], axis=1)
df.rename(columns={'code': 'display_code'}, inplace=True)

# flatten the valueQuantity column
df = pd.concat([pd.json_normalize(df['valueQuantity']), df], axis=1)

df.drop(columns=['component_code', 'valueQuantity', 'system', 'code'], inplace=True)
detail_dfs['Observation.component'] = df
df.head()
# Out:
#    value  unit display_code                   display  \
# 0    136  mmHg       8480-6   Systolic Blood Pressure
# 1     86  mmHg       8462-4  Diastolic Blood Pressure
# 2    133  mmHg       8480-6   Systolic Blood Pressure
# 3     72  mmHg       8462-4  Diastolic Blood Pressure
# 4    109  mmHg       8480-6   Systolic Blood Pressure
#
#                          Observation_id
# 0  7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0
# 1  7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0
# 2  2e64f693-fe4f-4405-a0b4-25bd031f0660
# 3  2e64f693-fe4f-4405-a0b4-25bd031f0660
# 4  2e3a9af1-035a-44a5-97a5-5669a5c02e8b

# %%
df = detail_dfs['Observation']

# Rename and retype columns
df['effectiveDateTime'] = pd.to_datetime(df['effectiveDateTime'])
df.rename(columns={'subject.reference': 'patient_id', 'encounter.reference': 'encounter_id'}, inplace=True)
df['patient_id'] = df['patient_id'].apply(lambda x: str(x).split(':')[-1])
df['encounter_id'] = df['encounter_id'].apply(lambda x: str(x).split(':')[-1])

# Merge with Observation.valueCodeableConcept
df = df.merge(detail_dfs['Observation.valueCodeableConcept'], left_on='id', right_on='Observation_id', how='left')
df.drop(columns=['Observation_id', 'value_display'], inplace=True)

# Merge with Observation.code
df = df.merge(detail_dfs['Observation.code'], left_on='id', right_on='Observation_id', how='left')
df.drop(columns=['Observation_id', 'observation_display'], inplace=True)

detail_dfs['Observation.result'] = df[['id', 'valueQuantity.value', 'valueQuantity.unit', 'valueQuantity.system', 'valueQuantity.code', 'value_code', 'observation_code']]

df.drop(columns=['valueQuantity.value', 'valueQuantity.unit', 'valueQuantity.system', 'valueQuantity.code', 'value_code', 'resourceType'], inplace=True)

detail_dfs['Observation'] = df

detail_dfs['Observation'].head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\2802718056.py:4: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['effectiveDateTime'] = pd.to_datetime(df['effectiveDateTime'])
#                                      id status          effectiveDateTime  \
# 0  7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0  final  2010-05-12 10:33:51-04:00
# 1  cac21874-494f-49f6-8074-1d517a62a7d3  final  2011-07-02 14:56:51-04:00
# 2  61d46e20-1a26-4fb9-ba74-e21c01bce443  final  2011-07-02 14:56:51-04:00
# 3  62b7938f-5fab-4067-8e6a-fc4f8df284d3  final  2011-07-02 14:56:51-04:00
# 4  2e64f693-fe4f-4405-a0b4-25bd031f0660  final  2012-06-03 09:20:31-04:00
#
#                              patient_id                          encounter_id  \
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 1  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  f5b01614-f569-4e9e-b482-cc0231a7c20a
# 2  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  f5b01614-f569-4e9e-b482-cc0231a7c20a
# 3  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  f5b01614-f569-4e9e-b482-cc0231a7c20a
# 4  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  1460d856-b01a-4c3b-b8c7-07fd86cac5fe
#
#   observation_code
# 0          55284-4
# 1           8302-2
# 2          29463-7
# 3          39156-5
# 4          55284-4

# %%
df = detail_dfs['Observation.result']
df.rename(columns={'id': 'Observation_id'}, inplace=True)

df = df.merge(detail_dfs['Observation.component'], left_on='Observation_id', right_on='Observation_id', how='outer')

df['value'] = df['value'].combine_first(df['valueQuantity.value'])
df['unit'] = df['unit'].combine_first(df['valueQuantity.unit'])
df['display_code'] = df['display_code'].combine_first(df['observation_code'])
df['value'] = df['value_code'].combine_first(df['value'])
df.loc[df['value_code'].notna(), 'unit'] = 'conceptable'

df.drop(columns=['valueQuantity.value', 'valueQuantity.unit', 'valueQuantity.system', 'valueQuantity.code', 'value_code', 'observation_code', 'display'], inplace=True)
detail_dfs['Observation.result'] = df
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\2910551018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'id': 'Observation_id'}, inplace=True)
#                          Observation_id       value   unit display_code
# 0  000846ce-2c8a-4f15-b78d-2a3946dd7511   33.455703  kg/m2      39156-5
# 1  00094faa-4c6d-408a-b4b2-9cf695b69993  126.733262     kg      29463-7
# 2  00107bdb-af53-45a2-acb6-692be5af03f1        48.0      %      19926-5
# 3  0012e3b4-1229-480b-9da4-a131eceeb7e2       141.0  mg/dL       2571-8
# 4  0014b791-810f-4bae-a534-613f3b20aa89   158.88273     cm       8302-2

# %%
df = detail_dfs['Observation.component']

df = df[['display_code', 'display']]
df.drop_duplicates(inplace=True)

df.rename(columns={'display': 'observation_display', 'display_code': 'observation_code'}, inplace=True)

detail_dfs['Observation.code'] = pd.concat([detail_dfs['Observation.code'], df], ignore_index=True)
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\788051776.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\788051776.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'display': 'observation_display', 'display_code': 'observation_code'}, inplace=True)
#   observation_code       observation_display
# 0           8480-6   Systolic Blood Pressure
# 1           8462-4  Diastolic Blood Pressure

# %%
detail_dfs['Observation.code'].drop(columns=['Observation_id'], inplace=True)
detail_dfs['Observation.code'].drop_duplicates(inplace=True)

detail_dfs['Observation.valueCodeableConcept'].drop(columns=['Observation_id'], inplace=True)
detail_dfs['Observation.valueCodeableConcept'].drop_duplicates(inplace=True)

detail_dfs.pop('Observation.valueCodeableConcept.coding', None)
detail_dfs.pop('Observation.code.coding', None)

detail_dfs['Observation.code'].info()
detail_dfs['Observation.valueCodeableConcept'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 19380
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   observation_code     52 non-null     object
#  1   observation_display  52 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   value_code     6 non-null      object
#  1   value_display  6 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes

# %% [markdown]
# ### DiagnosticResult adjust data

# %%
df = detail_dfs['DiagnosticReport.code.coding']
df.drop(columns=['system'], inplace=True)

detail_dfs['DiagnosticReport.code'] = df
df.head()
# Out:
#       code                display                   DiagnosticReport_id
# 0  57698-3            Lipid Panel  ff1b01ef-8d21-48da-8f7e-b3db4d62417c
# 1  51990-0  Basic Metabolic Panel  60a3adfa-b06c-44bd-9285-c181b8c3d88e
# 2  57698-3            Lipid Panel  d50e1609-872b-43e7-8679-42a980260ac3
# 3  51990-0  Basic Metabolic Panel  91659759-ce79-431f-bc24-fcffa0b0f53d
# 4  57698-3            Lipid Panel  b831beff-cda7-42f8-b524-24f3512766ed

# %%
detail_dfs['DiagnosticReport.code'].head()
# Out:
#       code                                            display
# 0  57698-3                                        Lipid Panel
# 1  51990-0                              Basic Metabolic Panel
# 7  69409-1  U.S. standard certificate of death - 2003 revi...

# %%
df = detail_dfs['DiagnosticReport.performer']

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189 entries, 0 to 1188
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   display              1189 non-null   object
#  1   DiagnosticReport_id  1189 non-null   object
# dtypes: object(2)
# memory usage: 18.7+ KB

# %%
df = detail_dfs['DiagnosticReport.result']
df['reference'] = df['reference'].apply(lambda x: str(x).split(':')[-1])

detail_dfs['DiagnosticReport.result'] = df
df.head()
# Out:
#                               reference                               display  \
# 0  98ab19e8-4623-4e30-8782-83620ed34f17                     Total Cholesterol
# 1  aeff25de-10b9-4a2b-8740-8aa66d34f1cd                         Triglycerides
# 2  7ae8d33d-97a2-4d62-b645-f88654478e67   Low Density Lipoprotein Cholesterol
# 3  3a82f21d-f33d-497f-99fb-523b8c7154af  High Density Lipoprotein Cholesterol
# 4  d1137901-93eb-4965-bf0d-7a6a62f8e138                               Glucose
#
#                     DiagnosticReport_id
# 0  ff1b01ef-8d21-48da-8f7e-b3db4d62417c
# 1  ff1b01ef-8d21-48da-8f7e-b3db4d62417c
# 2  ff1b01ef-8d21-48da-8f7e-b3db4d62417c
# 3  ff1b01ef-8d21-48da-8f7e-b3db4d62417c
# 4  60a3adfa-b06c-44bd-9285-c181b8c3d88e

# %%
detail_dfs['DiagnosticReport.result']['display'].value_counts()
# Out:
# display
# Glucose                                              619
# Sodium                                               619
# Calcium                                              619
# Creatinine                                           619
# Urea Nitrogen                                        619
# Potassium                                            619
# Chloride                                             619
# Carbon Dioxide                                       619
# Total Cholesterol                                    532
# High Density Lipoprotein Cholesterol                 532
# Low Density Lipoprotein Cholesterol                  532
# Triglycerides                                        532
# Cause of Death [US Standard Certificate of Death]     38
# Name: count, dtype: Int64

# %%
df = detail_dfs['DiagnosticReport']

df['effectiveDateTime'] = pd.to_datetime(df['effectiveDateTime'])
df['issued'] = pd.to_datetime(df['issued'])

df['subject_id'] = df['subject.reference'].apply(lambda x: str(x).split(':')[-1])
df['encounter_id'] = df['encounter.reference'].apply(lambda x: str(x).split(':')[-1])

df = df.merge(detail_dfs['DiagnosticReport.code'], left_on='id', right_on='DiagnosticReport_id', how='left')
df.drop(columns=['DiagnosticReport_id', 'display'], inplace=True)
df = df.rename(columns={'code': 'report_code'})

detail_dfs['DiagnosticReport.code'].drop(columns=['DiagnosticReport_id'], inplace=True)
detail_dfs['DiagnosticReport.code'].drop_duplicates(inplace=True)

df.drop(columns=['subject.reference', 'encounter.reference', 'resourceType'], inplace=True)

detail_dfs['DiagnosticReport'] = df
df.head()
# Out:
#                                      id status          effectiveDateTime  \
# 0  ff1b01ef-8d21-48da-8f7e-b3db4d62417c  final  2017-02-22 13:52:56-05:00
# 1  60a3adfa-b06c-44bd-9285-c181b8c3d88e  final  2011-06-02 20:58:47-04:00
# 2  d50e1609-872b-43e7-8679-42a980260ac3  final  2015-05-15 04:15:28-04:00
# 3  91659759-ce79-431f-bc24-fcffa0b0f53d  final  2010-07-28 22:24:43-04:00
# 4  b831beff-cda7-42f8-b524-24f3512766ed  final  2010-07-05 17:41:42-04:00
#
#                       issued                            subject_id  \
# 0  2017-02-22 13:52:56-05:00  117335bb-33ff-4897-ac27-af4b3f11135f
# 1  2011-06-02 20:58:47-04:00  3a5357d9-13f3-42de-8fdc-14a1a6cae148
# 2  2015-05-15 04:15:28-04:00  aa3973d9-b64f-4a36-8cb6-f2719080b52f
# 3  2010-07-28 22:24:43-04:00  24950485-2ecd-4405-bb76-e92a3259adc4
# 4  2010-07-05 17:41:42-04:00  edfbc3f7-9ec5-472c-bd5c-ac9041927441
#
#                            encounter_id report_code
# 0  5948265c-890d-4b41-9b89-61b195cfa4c5     57698-3
# 1  d53f9c2a-250a-49a9-9f8d-321ca30034bb     51990-0
# 2  638fee81-9b8f-4896-8536-407e34db67c0     57698-3
# 3  3bf22b8b-0a73-4bce-a6d9-670c1ff5c4c6     51990-0
# 4  f2118807-b201-48e3-8271-8074781be72c     57698-3

# %% [markdown]
# ### AllergyIntolerance adjust data

# %%
df = detail_dfs['AllergyIntolerance']

df.drop(columns=['resourceType'], inplace=True)
df = df.dropna(how='all')
df = df.explode('code.coding', ignore_index=True)
df['display'] = df['code.coding'].apply(lambda x: x['display'])
df['code'] = df['code.coding'].apply(lambda x: x['code'])

df['patient_id'] = df['patient.reference'].apply(lambda x: str(x).split(':')[-1])
df['assertedDate'] = pd.to_datetime(df['assertedDate'])

df['category'] = df['category'].apply(lambda x: ','.join(x))

df.drop(columns=['code.coding', 'patient.reference'], inplace=True)

detail_dfs['AllergyIntolerance'] = df
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11140\3571892836.py:10: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['assertedDate'] = pd.to_datetime(df['assertedDate'])
#   clinicalStatus     type category criticality               assertedDate  \
# 0         active  allergy     food         low  1945-01-03 16:27:18-04:00
# 1         active  allergy     food        high  1945-01-03 16:27:18-04:00
# 2         active  allergy     food         low  1945-01-03 16:27:18-04:00
# 3         active  allergy     food        high  1989-08-30 10:46:39-04:00
# 4         active  allergy     food         low  1989-08-30 10:46:39-04:00
#
#                    display       code                            patient_id
# 0          Allergy to fish  417532002  a0dcd747-1d40-40fd-8e42-1f9395f034ca
# 1  Allergy to grass pollen  418689008  a0dcd747-1d40-40fd-8e42-1f9395f034ca
# 2         Allergy to mould  419474003  a0dcd747-1d40-40fd-8e42-1f9395f034ca
# 3        Shellfish allergy  300913006  ddd6fcc5-4a60-450d-a55c-927113ec312e
# 4   Allergy to tree pollen  419263009  ddd6fcc5-4a60-450d-a55c-927113ec312e

# %% [markdown]
# ### CarePlan adjust data

# %%
def explode_flatten_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    This function explodes lists and flattens dictionaries in a dataframe until there are none.
    """
    while True:
        # Identify columns that need to be exploded or flattened
        list_cols = [col for col in df.columns if isinstance(df[df[col].notna()][col].iloc[0], list)]
        dict_cols = [col for col in df.columns if isinstance(df[df[col].notna()][col].iloc[0], dict)]
        
        if not list_cols and not dict_cols:
            break
        
        # Explode list columns
        for col in list_cols:
            df = df.explode(col, ignore_index=True)
        
        # Flatten dictionary columns
        for col in dict_cols:
            normalized_data = pd.json_normalize(df[col])
            normalized_data.columns = [f"{col}.{subcol}" for subcol in normalized_data.columns]
            df = pd.concat([df.drop(columns=[col]), normalized_data], axis=1)
    
    return df

# %%
from typing import List


def extract_id(df: pd.DataFrame, cols: List[str]) -> pd.DataFrame:
    """
    Extract the id from a reference column
    """
    for col in cols:
        new_col = col.split('.')[0] + '_id'
        df[new_col] = df[col].apply(lambda x: str(x).split(':')[-1])
        df.loc[df[col].isna(), new_col] = np.nan
        df.drop(columns=[col], inplace=True)
    return df

# %%
df = detail_dfs['CarePlan']

df.drop(columns=['resourceType'], inplace=True)

df = explode_flatten_df(df)

df = extract_id(df, ['subject.reference', 'context.reference', 'addresses.reference'])

df.drop(columns=['category.coding.system', 'activity.detail.code.coding.system'], inplace=True)

detail_dfs['CarePlan.category'] = df[['category.coding.code', 'category.coding.display']].drop_duplicates()
detail_dfs['CarePlan.activity'] = df[['activity.detail.code.coding.code', 'activity.detail.code.coding.display']].drop_duplicates()

df.rename(columns={'category.coding.code': 'category_code', 'activity.detail.code.coding.code': 'activity_code', 'activity.detail.status': 
'activity_status'}, inplace=True)
df.drop(columns=['category.coding.display', 'activity.detail.code.coding.display'], inplace=True)

detail_dfs['CarePlan'] = df
df.head()
# Out:
#       status period.start  period.end activity_status category_code  \
# 0     active   1968-03-07         NaN     in-progress     698360004
# 1     active   1968-03-07         NaN     in-progress     698360004
# 2  completed   1996-03-14  1996-05-12       completed      53950000
# 3  completed   1996-03-14  1996-05-12       completed      53950000
# 4  completed   2001-12-13  2002-06-25       completed      53950000
#
#   activity_code                            subject_id  \
# 0     160670007  c71d235f-9b58-4106-b744-c554da5e13fa
# 1     229065009  c71d235f-9b58-4106-b744-c554da5e13fa
# 2     304510005  509474a0-baf3-48f2-a595-67b6e2b34c87
# 3     371605008  509474a0-baf3-48f2-a595-67b6e2b34c87
# 4     304510005  509474a0-baf3-48f2-a595-67b6e2b34c87
#
#                              context_id                          addresses_id
# 0  0295554d-c9f6-402f-bcbc-0a818521f4c5  66868a39-d41a-4acb-a3a2-202093909119
# 1  0295554d-c9f6-402f-bcbc-0a818521f4c5  66868a39-d41a-4acb-a3a2-202093909119
# 2  d9db693d-4bba-4571-bba9-ae6c1575b945                                   NaN
# 3  d9db693d-4bba-4571-bba9-ae6c1575b945                                   NaN
# 4  d9db693d-4bba-4571-bba9-ae6c1575b945                                   NaN

# %% [markdown]
# ### Immunization adjust data

# %%
df = detail_dfs['Immunization']

df.drop(columns=['resourceType'], inplace=True)

df = explode_flatten_df(df)

df = extract_id(df, ['patient.reference', 'encounter.reference'])

df.drop(columns=['vaccineCode.coding.system'], inplace=True)

detail_dfs['Immunization.vaccineCode'] = df[['vaccineCode.coding.code', 'vaccineCode.coding.display']].drop_duplicates()

df.rename(columns={'vaccineCode.coding.code': 'vaccine_code'}, inplace=True)
df.drop(columns=['vaccineCode.coding.display'], inplace=True)

detail_dfs['Immunization'] = df
df.head()
# Out:
#       status                       date wasNotGiven primarySource  \
# 0  completed  2016-05-13T09:03:20-04:00       False          True
# 1  completed  2010-09-28T21:56:11-04:00       False          True
# 2  completed  2011-10-15T19:42:43-04:00       False          True
# 3  completed  2013-05-10T03:21:09-04:00       False          True
# 4  completed  2013-07-19T22:54:37-04:00       False          True
#
#   vaccine_code                            patient_id  \
# 0          140  80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 1          140  509474a0-baf3-48f2-a595-67b6e2b34c87
# 2          140  509474a0-baf3-48f2-a595-67b6e2b34c87
# 3           49  65dfe191-c7ef-4148-8f12-49f832525d4c
# 4           10  65dfe191-c7ef-4148-8f12-49f832525d4c
#
#                            encounter_id
# 0  c4119ed9-02d5-4fb3-a51e-7d7cccdf4085
# 1  d9db693d-4bba-4571-bba9-ae6c1575b945
# 2  f64fee9b-4eef-4238-a887-0f702c95e039
# 3  27bcacf8-f83d-422c-8c1e-ea99b8ed8c66
# 4  5678920f-d282-46dc-be87-2a0a93563f15

# %% [markdown]
# ### MedicationRequest adjust data

# %%
df = detail_dfs['MedicationRequest']

df.drop(columns=['resourceType'], inplace=True)
df = explode_flatten_df(df)

df = extract_id(df, ['patient.reference', 'context.reference', 'reasonReference.reference'])

df['id'] = df['dateWritten'] + "_" + df['patient_id']

def classify_medication(row):
    if pd.isna(row['dosageInstruction.asNeededBoolean']):
        return 'no instructions'
    elif row['dosageInstruction.asNeededBoolean']:
        return 'as needed'
    else:
        return 'scheduled'
    
df['medication_classification'] = df.apply(classify_medication, axis=1)

# DimMedication
# Extract unique medication information with relevant columns for medication coding and display.
detail_dfs['MedicationRequest.medication'] = df[['id', 'medicationCodeableConcept.coding.code', 'medicationCodeableConcept.coding.display']
                                                 ].drop_duplicates().rename(
    columns={'id': 'MedicationRequest_id',
             'medicationCodeableConcept.coding.code': 'CodingCode', 
             'medicationCodeableConcept.coding.display': 'CodingDisplay'}
)

# DimDosageInstruction
# Capture dosage instructions, including sequence, frequency, and period.
detail_dfs['MedicationRequest.dosageInstruction'] = df[['id', 'dosageInstruction.sequence', 
                                                        'dosageInstruction.asNeededBoolean', 
                                                        'dosageInstruction.timing.repeat.frequency',  
                                                        'dosageInstruction.timing.repeat.period', 
                                                        'dosageInstruction.timing.repeat.periodUnit', 
                                                        'dosageInstruction.doseQuantity.value',
                                                        'dosageInstruction.additionalInstructions.coding.code']].drop_duplicates().rename(
    columns={'id': 'MedicationRequest_id',
             'dosageInstruction.sequence': 'Sequence',
             'dosageInstruction.asNeededBoolean': 'AsNeededBoolean',
             'dosageInstruction.timing.repeat.frequency': 'Frequency',
             'dosageInstruction.timing.repeat.period': 'Period',
             'dosageInstruction.timing.repeat.periodUnit': 'PeriodUnit',
             'dosageInstruction.doseQuantity.value': 'DoseQuantityValue',
             'dosageInstruction.additionalInstructions.coding.code': 'AdditionalInstructionCode'}
)
detail_dfs['MedicationRequest.dosageInstruction'].dropna(subset=['Sequence'], inplace=True)

# DimAdditionalInstruction
# Extract additional instructions for dosage with coding system, code, and display information.
detail_dfs['MedicationRequest.additionalInstruction'] = df[['dosageInstruction.additionalInstructions.coding.code', 
                                                            'dosageInstruction.additionalInstructions.coding.display']].drop_duplicates().rename(
    columns={'dosageInstruction.additionalInstructions.coding.code': 'InstructionCode',
             'dosageInstruction.additionalInstructions.coding.display': 'InstructionDisplay'}
)
detail_dfs['MedicationRequest.additionalInstruction'].dropna(subset=['InstructionCode'], inplace=True)

# DimDispenseRequest
# Capture dispense request details with expected supply duration and quantity information.
detail_dfs['MedicationRequest.dispenseRequest'] = df[['id', 
                                                      'dispenseRequest.numberOfRepeatsAllowed', 
                                                      'dispenseRequest.quantity.value', 
                                                      'dispenseRequest.quantity.unit', 
                                                      'dispenseRequest.expectedSupplyDuration.value', 
                                                      'dispenseRequest.expectedSupplyDuration.unit', 
                                                      'dispenseRequest.expectedSupplyDuration.code']].drop_duplicates().rename(
    columns={'id': 'MedicationRequest_id',
             'dispenseRequest.numberOfRepeatsAllowed': 'NumberOfRepeatsAllowed',
             'dispenseRequest.quantity.value': 'QuantityValue', 
             'dispenseRequest.quantity.unit': 'QuantityUnit',
             'dispenseRequest.expectedSupplyDuration.value': 'ExpectedSupplyDurationValue', 
             'dispenseRequest.expectedSupplyDuration.unit': 'ExpectedSupplyDurationUnit',
             'dispenseRequest.expectedSupplyDuration.code': 'ExpectedSupplyDurationCode'}
)
detail_dfs['MedicationRequest.dispenseRequest'].dropna(subset=['QuantityValue'], inplace=True)

# Main Medication Request Table
# Retain only high-level columns, including medication code and metadata for main medication request table.
main_df = df[['id', 'status', 'dateWritten', 'patient_id', 'context_id', 'reasonReference_id', 
              'medicationCodeableConcept.coding.code', 'medication_classification']].drop_duplicates().rename(
    columns={'id': 'MedicationRequest_id',
             'medicationCodeableConcept.coding.code': 'MedicationCode'}
)

detail_dfs['MedicationRequest'] = main_df
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 29 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   status                                                   1291 non-null   object
#  1   dateWritten                                              1291 non-null   object
#  2   dispenseRequest.numberOfRepeatsAllowed                   90 non-null     float64
#  3   dispenseRequest.quantity.value                           90 non-null     float64
#  4   dispenseRequest.quantity.unit                            90 non-null     object
#  5   dispenseRequest.expectedSupplyDuration.value             90 non-null     float64
#  6   dispenseRequest.expectedSupplyDuration.unit              90 non-null     object
#  7   dispenseRequest.expectedSupplyDuration.system            90 non-null     object
#  8   dispenseRequest.expectedSupplyDuration.code              90 non-null     object
#  9   dosageInstruction.sequence                               497 non-null    float64
#  10  dosageInstruction.asNeededBoolean                        497 non-null    object
#  11  dosageInstruction.timing.repeat.frequency                90 non-null     float64
#  12  dosageInstruction.timing.repeat.period                   90 non-null     float64
#  13  dosageInstruction.timing.repeat.periodUnit               90 non-null     object
#  14  dosageInstruction.doseQuantity.value                     90 non-null     float64
#  15  stage.coding.system                                      1291 non-null   object
#  16  stage.coding.code                                        1291 non-null   object
#  17  medicationCodeableConcept.coding.system                  1291 non-null   object
#  18  medicationCodeableConcept.coding.code                    1291 non-null   object
#  19  medicationCodeableConcept.coding.display                 1291 non-null   object
#  20  dosageInstruction.additionalInstructions.coding.system   58 non-null     object
#  21  dosageInstruction.additionalInstructions.coding.code     58 non-null     object
#  22  dosageInstruction.additionalInstructions.coding.display  58 non-null     object
#  23  patient_id                                               1291 non-null   object
#  24  context_id                                               1291 non-null   object
#  25  reasonReference_id                                       455 non-null    object
#  26  id                                                       1291 non-null   object
#  27  medication_classification                                2544 non-null   object
#  28  additional_instruction                                   2544 non-null   bool
# dtypes: bool(1), float64(7), object(21)
# memory usage: 559.1+ KB

# %%
detail_dfs['MedicationRequest.additionalInstruction'].head()
# Out:
#                                MedicationRequest_id InstructionCode  \
# 10  2015-01-22_98be5239-0275-45df-96b0-4faa7995fad9       418577003
# 21  2010-03-24_3877e505-ecc0-4a70-8e58-9ac93fb301a5       418577003
# 22  2013-02-02_fa501926-e785-4761-bec5-bc53de5f4222       418577003
# 30  2010-05-23_2e1e5ade-594b-4ef9-9313-4dac10ac1881       418577003
# 32  2013-07-26_aa84af31-90c0-4274-b207-3e7d1b8e6953       418577003
#
#                                    InstructionDisplay
# 10  Take at regular intervals. Complete the prescr...
# 21  Take at regular intervals. Complete the prescr...
# 22  Take at regular intervals. Complete the prescr...
# 30  Take at regular intervals. Complete the prescr...
# 32  Take at regular intervals. Complete the prescr...

# %% [markdown]
# ### Procedure adjust data

# %%
df = detail_dfs['Procedure']

df.drop(columns=['resourceType'], inplace=True)
df = explode_flatten_df(df)
df.dropna(how='all', inplace=True)
df['performedPeriod.start'] = df['performedPeriod.start'].combine_first(df['performedDateTime'])
df['performedPeriod.end'] = df['performedPeriod.end'].combine_first(df['performedDateTime'])
df.drop(columns=['performedDateTime'], inplace=True)

detail_dfs['Procedure.type'] = df[['code.coding.code', 'code.coding.display']].drop_duplicates().rename(
    columns={'code.coding.code': 'ProcedureCode', 'code.coding.display': 'ProcedureDisplay'}
)

df = extract_id(df, ['subject.reference', 'encounter.reference', 'reasonReference.reference'])

df.drop(columns=['code.coding.system', 'code.text', 'code.coding.display'], inplace=True)
df = df.rename(columns={'code.coding.code': 'ProcedureCode', 'code.coding.display': 'ProcedureDisplay'})

detail_dfs['Procedure'] = df
df.head()
# Out:
#       status      performedPeriod.start        performedPeriod.end  \
# 0  completed  2011-10-15T19:42:43-04:00  2011-10-15T19:42:43-04:00
# 1  completed  2013-12-18T11:54:32-05:00  2013-12-18T11:54:32-05:00
# 2  completed  2014-02-12T21:29:48-05:00  2014-02-12T21:29:48-05:00
# 3  completed  2013-04-21T02:07:56-04:00  2013-04-21T03:08:21-04:00
# 4  completed  2011-11-21T04:02:10-05:00  2011-11-21T04:31:11-05:00
#
#      ProcedureCode                            subject_id  \
# 0  428191000124101  509474a0-baf3-48f2-a595-67b6e2b34c87
# 1  428191000124101  1694897b-912e-401f-a135-aa59857a401e
# 2        274031008  a0dcd747-1d40-40fd-8e42-1f9395f034ca
# 3        305428000  00d869e2-6793-4ebf-9340-38bf18d223c4
# 4        288086009  bd0acd69-580e-4896-9974-2ad9d041ca0b
#
#                            encounter_id                    reasonReference_id
# 0  f64fee9b-4eef-4238-a887-0f702c95e039                                   NaN
# 1  56155626-b08a-44a6-82e8-9b3e862965e5                                   NaN
# 2  fc59c225-917b-4485-a399-38c2c1d545a2  5b8bdf82-c4f8-4b8a-ac6b-441ac775cd1d
# 3  8625df2e-3c5d-4dc2-83c7-714a126d407e  3933d233-e42b-446f-b6d5-2124f7d650e6
# 4  afee7487-a8bb-48b2-b1bd-774bebdaed00  88c1ae16-3abd-45a8-946e-2dd82565b11f

# %%
# Check if code.coding.display is the same as code.text
detail_dfs['Procedure.type'].value_counts().head()
# Out:
# ProcedureCode     ProcedureDisplay
# 1015401000000102  Fecal occult blood test              1
# 112790001         Nasal sinus endoscopy (procedure)    1
# 11466000          Cesarean section                     1
# 117015009         Throat culture (procedure)           1
# 127783003         Spirometry (procedure)               1
# Name: count, dtype: int64

# %% [markdown]
# ### Overview
# This part will show what dataframe we have so far

# %%
dfs = [df for df in detail_dfs]
dfs.sort()
print(*dfs, sep='\n')
# Out:
# AllergyIntolerance
# CarePlan
# CarePlan.activity
# CarePlan.category
# Condition
# Condition.code
# DiagnosticReport
# DiagnosticReport.code
# DiagnosticReport.performer
# DiagnosticReport.result
# Encounter
# Encounter.reason
# Encounter.type
# Immunization
# Immunization.vaccineCode
# MedicationRequest
# MedicationRequest.additionalInstruction
# MedicationRequest.dispenseRequest
# MedicationRequest.dosageInstruction
# MedicationRequest.medication
# Observation
# Observation.code
# Observation.component
# Observation.result
# Observation.valueCodeableConcept
# Patient
# Patient.address
# Patient.extension
# Patient.identifier
# Patient.maritalStatus
# Patient.name
# Patient.photo
# Patient.telecom
# Procedure
# Procedure.type

# %%
# Remove .coding from the dfs
detail_dfs.pop('DiagnosticReport.code.coding', None)
detail_dfs.pop('Patient.maritalStatus.coding', None)

detail_dfs = dict(sorted(detail_dfs.items(), key=lambda x: x[0]))
for df in detail_dfs:
    # Drop nan rows from the dataframes
    detail_dfs[df].dropna(how='all', inplace=True)
    # Drop duplicates from the dataframes
    detail_dfs[df].drop_duplicates(inplace=True)

    # Cast best types for the columns
    detail_dfs[df] = detail_dfs[df].convert_dtypes()
    print(f"\nResource type: {df}")
    detail_dfs[df].info(memory_usage=False)
# Out:
# Resource type: AllergyIntolerance
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   clinicalStatus  278 non-null    string
#  1   type            278 non-null    string
#  2   category        278 non-null    string
#  3   criticality     278 non-null    string
#  4   assertedDate    278 non-null    object
#  5   display         278 non-null    string
#  6   code            278 non-null    string
#  7   patient_id      278 non-null    string
# dtypes: object(1), string(7)
# Resource type: CarePlan
# <class 'pandas.core.frame.DataFrame'>
# Index: 2096 entries, 0 to 3052
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   status           2096 non-null   string
#  1   period.start     2096 non-null   string
#  2   period.end       1096 non-null   string
#  3   activity_status  2096 non-null   string
#  4   category_code    2096 non-null   string
#  5   activity_code    2096 non-null   string
#  6   subject_id       2096 non-null   string
#  7   context_id       2096 non-null   string
#  8   addresses_id     1591 non-null   string
# dtypes: string(9)
# Resource type: CarePlan.activity
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 0 to 2291
# Data columns (total 2 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   activity.detail.code.coding.code     45 non-null     string
#  1   activity.detail.code.coding.display  45 non-null     string
# dtypes: string(2)
# Resource type: CarePlan.category
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 2290
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   category.coding.code     22 non-null     string
#  1   category.coding.display  22 non-null     string
# dtypes: string(2)
# Resource type: Condition
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1917 non-null   string
#  1   clinicalStatus      1917 non-null   string
#  2   verificationStatus  1917 non-null   string
#  3   onsetDateTime       1917 non-null   object
#  4   abatementDateTime   1178 non-null   object
#  5   patient_id          1917 non-null   string
#  6   encounter_id        1917 non-null   string
#  7   condition_code      1917 non-null   string
# dtypes: object(2), string(6)
# Resource type: Condition.code
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 0 to 1876
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   condition_code     90 non-null     string
#  1   condition_display  90 non-null     string
# dtypes: string(2)
# Resource type: DiagnosticReport
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1189 non-null   string
#  1   status             1189 non-null   string
#  2   effectiveDateTime  1189 non-null   object
#  3   issued             1189 non-null   object
#  4   subject_id         1190 non-null   string
#  5   encounter_id       1190 non-null   string
#  6   report_code        1189 non-null   string
# dtypes: object(2), string(5)
# Resource type: DiagnosticReport.code
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   code     3 non-null      string
#  1   display  3 non-null      string
# dtypes: string(2)
# Resource type: DiagnosticReport.performer
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189 entries, 0 to 1188
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   display              1189 non-null   string
#  1   DiagnosticReport_id  1189 non-null   string
# dtypes: string(2)
# Resource type: DiagnosticReport.result
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7118 entries, 0 to 7117
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   reference            7118 non-null   string
#  1   display              7118 non-null   string
#  2   DiagnosticReport_id  7118 non-null   string
# dtypes: string(3)
# Resource type: Encounter
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5103 entries, 0 to 5102
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            5103 non-null   string
#  1   status        5103 non-null   string
#  2   class.code    5103 non-null   string
#  3   period_start  5103 non-null   object
#  4   period_end    5103 non-null   object
#  5   patient_id    5103 non-null   string
#  6   text          5103 non-null   string
#  7   type_code     5103 non-null   string
#  8   reason_code   1485 non-null   string
# dtypes: object(2), string(7)
# Resource type: Encounter.reason
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 0 to 1452
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reason_code     44 non-null     string
#  1   reason_display  44 non-null     string
# dtypes: string(2)
# Resource type: Encounter.type
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 0 to 3184
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       26 non-null     string
#  1   type_code  26 non-null     string
# dtypes: string(2)
# Resource type: Immunization
# <class 'pandas.core.frame.DataFrame'>
# Index: 3686 entries, 0 to 6975
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status         3686 non-null   string
#  1   date           3686 non-null   string
#  2   wasNotGiven    3686 non-null   boolean
#  3   primarySource  3686 non-null   boolean
#  4   vaccine_code   3686 non-null   string
#  5   patient_id     3686 non-null   string
#  6   encounter_id   3686 non-null   string
# dtypes: boolean(2), string(5)
# Resource type: Immunization.vaccineCode
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 277
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   vaccineCode.coding.code     16 non-null     string
#  1   vaccineCode.coding.display  16 non-null     string
# dtypes: string(2)
# Resource type: MedicationRequest
# <class 'pandas.core.frame.DataFrame'>
# Index: 1292 entries, 0 to 2543
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   MedicationRequest_id       1291 non-null   string
#  1   status                     1291 non-null   string
#  2   dateWritten                1291 non-null   string
#  3   patient_id                 1291 non-null   string
#  4   context_id                 1291 non-null   string
#  5   reasonReference_id         455 non-null    string
#  6   MedicationCode             1291 non-null   string
#  7   medication_classification  1292 non-null   string
# dtypes: string(8)
# Resource type: MedicationRequest.additionalInstruction
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 10 to 2524
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MedicationRequest_id  58 non-null     string
#  1   InstructionCode       58 non-null     string
#  2   InstructionDisplay    58 non-null     string
# dtypes: string(3)
# Resource type: MedicationRequest.dispenseRequest
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 9 to 2524
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MedicationRequest_id         90 non-null     string
#  1   NumberOfRepeatsAllowed       90 non-null     Int64
#  2   QuantityValue                90 non-null     Int64
#  3   QuantityUnit                 90 non-null     string
#  4   ExpectedSupplyDurationValue  90 non-null     Int64
#  5   ExpectedSupplyDurationUnit   90 non-null     string
#  6   ExpectedSupplyDurationCode   90 non-null     string
# dtypes: Int64(3), string(4)
# Resource type: MedicationRequest.dosageInstruction
# <class 'pandas.core.frame.DataFrame'>
# Index: 431 entries, 1 to 2533
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MedicationRequest_id   431 non-null    string
#  1   Sequence               431 non-null    Int64
#  2   AsNeededBoolean        431 non-null    boolean
#  3   Frequency              90 non-null     Int64
#  4   Period                 90 non-null     Int64
#  5   PeriodUnit             90 non-null     string
#  6   DoseQuantityValue      90 non-null     Int64
#  7   AdditionalInstruction  431 non-null    boolean
# dtypes: Int64(4), boolean(2), string(2)
# Resource type: MedicationRequest.medication
# <class 'pandas.core.frame.DataFrame'>
# Index: 1291 entries, 0 to 2543
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MedicationRequest_id  1291 non-null   string
#  1   CodingCode            1291 non-null   string
#  2   CodingDisplay         1291 non-null   string
# dtypes: string(3)
# Resource type: Observation
# <class 'pandas.core.frame.DataFrame'>
# Index: 19380 entries, 0 to 28696
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 19379 non-null  string
#  1   status             19379 non-null  string
#  2   effectiveDateTime  19379 non-null  object
#  3   patient_id         19380 non-null  string
#  4   encounter_id       19380 non-null  string
#  5   observation_code   19379 non-null  string
# dtypes: object(1), string(5)
# Resource type: Observation.code
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 19380
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   observation_code     52 non-null     string
#  1   observation_display  52 non-null     string
# dtypes: string(2)
# Resource type: Observation.component
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4836 entries, 0 to 4835
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   value           4836 non-null   Int64
#  1   unit            4836 non-null   string
#  2   display_code    4836 non-null   string
#  3   display         4836 non-null   string
#  4   Observation_id  4836 non-null   string
# dtypes: Int64(1), string(4)
# Resource type: Observation.result
# <class 'pandas.core.frame.DataFrame'>
# Index: 21797 entries, 0 to 21796
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Observation_id  21797 non-null  string
#  1   value           21797 non-null  object
#  2   unit            21797 non-null  string
#  3   display_code    21797 non-null  string
# dtypes: object(1), string(3)
# Resource type: Observation.valueCodeableConcept
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   value_code     6 non-null      string
#  1   value_display  6 non-null      string
# dtypes: string(2)
# Resource type: Patient
# <class 'pandas.core.frame.DataFrame'>
# Index: 531 entries, 0 to 1053
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    531 non-null    string
#  1   gender                531 non-null    string
#  2   birthDate             531 non-null    datetime64[ns]
#  3   multipleBirthBoolean  531 non-null    boolean
#  4   deceasedDateTime      116 non-null    string
#  5   multipleBirthInteger  9 non-null      Int64
#  6   maritalStatus         378 non-null    string
# dtypes: Int64(1), boolean(1), datetime64[ns](1), string(4)
# Resource type: Patient.address
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   line        531 non-null    string
#  1   city        531 non-null    string
#  2   state       531 non-null    string
#  3   postalCode  531 non-null    string
#  4   Patient_id  531 non-null    string
#  5   latitude    531 non-null    Float64
#  6   longitude   531 non-null    Float64
# dtypes: Float64(2), string(5)
# Resource type: Patient.extension
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_id      2664 non-null   string
#  1   extension_type  2664 non-null   string
#  2   value           2664 non-null   string
# dtypes: string(3)
# Resource type: Patient.identifier
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708 entries, 0 to 1707
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   value       1708 non-null   string
#  1   type        1708 non-null   string
#  2   Patient_id  1708 non-null   string
# dtypes: string(3)
# Resource type: Patient.maritalStatus
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   maritalStatus  378 non-null    string
#  1   Patient_id     378 non-null    string
# dtypes: string(2)
# Resource type: Patient.name
# <class 'pandas.core.frame.DataFrame'>
# Index: 691 entries, 0 to 690
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   use         691 non-null    string
#  1   family      691 non-null    string
#  2   given       691 non-null    string
#  3   prefix      426 non-null    string
#  4   Patient_id  691 non-null    string
#  5   suffix      3 non-null      string
# dtypes: string(6)
# Resource type: Patient.photo
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   contentType  531 non-null    string
#  1   data         531 non-null    string
#  2   title        531 non-null    string
#  3   Patient_id   531 non-null    string
# dtypes: string(4)
# Resource type: Patient.telecom
# <class 'pandas.core.frame.DataFrame'>
# Index: 531 entries, 0 to 530
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   system              531 non-null    string
#  1   value               531 non-null    string
#  2   use                 531 non-null    string
#  3   Patient_id          531 non-null    string
#  4   okayToLeaveMessage  531 non-null    boolean
# dtypes: boolean(1), string(4)
# Resource type: Procedure
# <class 'pandas.core.frame.DataFrame'>
# Index: 2467 entries, 0 to 4809
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   status                 2467 non-null   string
#  1   performedPeriod.start  2467 non-null   string
#  2   performedPeriod.end    2467 non-null   string
#  3   ProcedureCode          2467 non-null   string
#  4   subject_id             2467 non-null   string
#  5   encounter_id           2467 non-null   string
#  6   reasonReference_id     553 non-null    string
# dtypes: string(7)
# Resource type: Procedure.type
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 0 to 4775
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ProcedureCode     41 non-null     string
#  1   ProcedureDisplay  41 non-null     string
# dtypes: string(2)
